# %%
import tensorflow as tf
from tensorflow import keras 
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as img
# %matplotlib inline
import tensorflow.keras.backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from pylab import imread,subplot,imshow,show
import cv2
import os

# %%
train = ImageDataGenerator(rescale=1./255)
test =  ImageDataGenerator(rescale=1./255)
val =  ImageDataGenerator(rescale=1./255)

# %%
train='dataset/train/'

# %%
train_data = tf.keras.preprocessing.image_dataset_from_directory(
    train,
    validation_split=0.2,
    image_size=(224,224),
    batch_size=32,
    subset='training',
    seed=1000 )
# Out:
# Found 4704 files belonging to 4 classes.
# Using 3764 files for training.

# %%
val='dataset/train/'

# %%
val_data = tf.keras.preprocessing.image_dataset_from_directory(
    val,
    validation_split=0.2,
    image_size=(224,224),
    batch_size=32,
    subset='validation',
    seed=1000
    )
# Out:
# Found 4704 files belonging to 4 classes.
# Using 940 files for validation.

# %%
test='dataset/test/'

# %%
test_data=tf.keras.preprocessing.image_dataset_from_directory(
    test,
    image_size=(224,224),
    batch_size=32,
    seed=1000
    )
# Out:
# Found 1228 files belonging to 4 classes.

# %%
class_names = ['Bacterialblight', 'Blast', 'Brownspot', 'Tungro']

# %%
train_data.class_names = class_names
val_data.class_names = class_names

# %%
print(val_data)
# Out:
# <BatchDataset shapes: ((None, 224, 224, 3), (None,)), types: (tf.float32, tf.int32)>

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_data.take(1):
    for i in range(6):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(train_data.class_names[labels[i]])
        plt.axis("off")

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Input
from tensorflow.keras.layers import Dense

# %%
model=Sequential()

model.add(Conv2D(16,(3,3), activation='relu', input_shape=(224,224,3)))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32,(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(32,(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

# model.add(Conv2D(32,(3,3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(30,activation='relu'))
model.add(Dense(10,activation='relu'))
model.add(Dense(100,activation='relu'))
model.add(Dense(133,activation='relu'))
model.add(Dense(4,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 16)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 111, 111, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 54, 54, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 93312)             0
# _________________________________________________________________
# dense (Dense)                (None, 30)                2799390
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                310
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               1100
# _________________________________________________________________
# dense_3 (Dense)              (None, 133)               13433
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 536
# =================================================================
# Total params: 2,819,857
# Trainable params: 2,819,857
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(1e-4), loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
history = model.fit(train_data, validation_data=val_data, epochs=50)
# Out:
# Epoch 1/50
# 118/118 [==============================] - 15s 72ms/step - loss: 3.4182 - accuracy: 0.3757 - val_loss: 1.2331 - val_accuracy: 0.4096
# Epoch 2/50
# 118/118 [==============================] - 7s 61ms/step - loss: 1.1688 - accuracy: 0.5170 - val_loss: 1.1407 - val_accuracy: 0.4904
# Epoch 3/50
# 118/118 [==============================] - 7s 62ms/step - loss: 1.0830 - accuracy: 0.5638 - val_loss: 1.6735 - val_accuracy: 0.3606
# Epoch 4/50
# 118/118 [==============================] - 8s 64ms/step - loss: 0.9393 - accuracy: 0.6211 - val_loss: 1.6619 - val_accuracy: 0.3723
# Epoch 5/50
# 118/118 [==============================] - 8s 69ms/step - loss: 0.9396 - accuracy: 0.6134 - val_loss: 1.8364 - val_accuracy: 0.3670
# Epoch 6/50
# 118/118 [==============================] - 8s 64ms/step - loss: 0.8045 - accuracy: 0.6793 - val_loss: 1.9220 - val_accuracy: 0.3457
# Epoch 7/50
# 118/118 [==============================] - 8s 63ms/step - loss: 0.7483 - accuracy: 0.7056 - val_loss: 2.2913 - val_accuracy: 0.3160
# Epoch 8/50
# 118/118 [==============================] - 8s 64ms/step - loss: 0.7161 - accuracy: 0.7274 - val_loss: 1.8420 - val_accuracy: 0.3840
# Epoch 9/50
# 118/118 [==============================] - 8s 63ms/step - loss: 0.6035 - accuracy: 0.7707 - val_loss: 1.5697 - val_accuracy: 0.4989
# Epoch 10/50
# 118/118 [==============================] - 8s 69ms/step - loss: 0.5051 - accuracy: 0.8172 - val_loss: 1.5828 - val_accuracy: 0.5915
# Epoch 11/50
# 118/118 [==============================] - 9s 74ms/step - loss: 0.4564 - accuracy: 0.8345 - val_loss: 1.4427 - val_accuracy: 0.6181
# Epoch 12/50
# 118/118 [==============================] - 7s 62ms/step - loss: 0.4148 - accuracy: 0.8515 - val_loss: 1.5279 - val_accuracy: 0.6128
# Epoch 13/50
# 118/118 [==============================] - 7s 62ms/step - loss: 0.3288 - accuracy: 0.8897 - val_loss: 1.3828 - val_accuracy: 0.6085
# Epoch 14/50
# 118/118 [==============================] - 7s 60ms/step - loss: 0.3352 - accuracy: 0.8850 - val_loss: 1.1916 - val_accuracy: 0.6383
# Epoch 15/50
# 118/118 [==============================] - 7s 61ms/step - loss: 0.2349 - accuracy: 0.9206 - val_loss: 1.2688 - val_accuracy: 0.5915
# Epoch 16/50
# 118/118 [==============================] - 8s 64ms/step - loss: 0.2026 - accuracy: 0.9352 - val_loss: 0.9944 - val_accuracy: 0.6596
# Epoch 17/50
# 118/118 [==============================] - 8s 63ms/step - loss: 0.1920 - accuracy: 0.9357 - val_loss: 0.9681 - val_accuracy: 0.6787
# Epoch 18/50
# 118/118 [==============================] - 7s 61ms/step - loss: 0.1464 - accuracy: 0.9527 - val_loss: 0.8768 - val_accuracy: 0.6957
# Epoch 19/50
# 118/118 [==============================] - 7s 60ms/step - loss: 0.1414 - accuracy: 0.9540 - val_loss: 0.9388 - val_accuracy: 0.7234
# Epoch 20/50
# 118/118 [==============================] - 7s 58ms/step - loss: 0.1249 - accuracy: 0.9601 - val_loss: 0.7870 - val_accuracy: 0.7628
# Epoch 21/50
# 118/118 [==============================] - 7s 58ms/step - loss: 0.1083 - accuracy: 0.9663 - val_loss: 0.7156 - val_accuracy: 0.7819
# Epoch 22/50
# 118/118 [==============================] - 7s 58ms/step - loss: 0.0913 - accuracy: 0.9713 - val_loss: 0.6567 - val_accuracy: 0.8074
# Epoch 23/50
# 118/118 [==============================] - 7s 58ms/step - loss: 0.0811 - accuracy: 0.9766 - val_loss: 0.6488 - val_accuracy: 0.8277
# Epoch 24/50
# 118/118 [==============================] - 7s 59ms/step - loss: 0.0734 - accuracy: 0.9798 - val_loss: 0.7060 - val_accuracy: 0.7968
# Epoch 25/50
# 118/118 [==============================] - 7s 58ms/step - loss: 0.0561 - accuracy: 0.9817 - val_loss: 0.5811 - val_accuracy: 0.8415
# Epoch 26/50
# 118/118 [==============================] - 7s 58ms/step - loss: 0.0663 - accuracy: 0.9782 - val_loss: 0.6310 - val_accuracy: 0.8287
# Epoch 27/50
# 118/118 [==============================] - 7s 58ms/step - loss: 0.0408 - accuracy: 0.9870 - val_loss: 0.6050 - val_accuracy: 0.8436
# Epoch 28/50
# 118/118 [==============================] - 7s 58ms/step - loss: 0.0354 - accuracy: 0.9894 - val_loss: 0.5911 - val_accuracy: 0.8234
# Epoch 29/50
# 118/118 [==============================] - 7s 60ms/step - loss: 0.0226 - accuracy: 0.9950 - val_loss: 0.5759 - val_accuracy: 0.8543
# Epoch 30/50
# 118/118 [==============================] - 7s 59ms/step - loss: 0.0215 - accuracy: 0.9947 - val_loss: 0.5190 - val_accuracy: 0.8617
# Epoch 31/50
# 118/118 [==============================] - 7s 59ms/step - loss: 0.0276 - accuracy: 0.9907 - val_loss: 0.7197 - val_accuracy: 0.8160
# Epoch 32/50
# 118/118 [==============================] - 7s 60ms/step - loss: 0.0693 - accuracy: 0.9787 - val_loss: 0.5088 - val_accuracy: 0.8553
# Epoch 33/50
# 118/118 [==============================] - 7s 59ms/step - loss: 0.0514 - accuracy: 0.9833 - val_loss: 0.5144 - val_accuracy: 0.8394
# Epoch 34/50
# 118/118 [==============================] - 7s 61ms/step - loss: 0.0224 - accuracy: 0.9942 - val_loss: 0.5900 - val_accuracy: 0.8404
# Epoch 35/50
# 118/118 [==============================] - 7s 60ms/step - loss: 0.0174 - accuracy: 0.9950 - val_loss: 0.5039 - val_accuracy: 0.8479
# Epoch 36/50
# 118/118 [==============================] - 7s 61ms/step - loss: 0.0222 - accuracy: 0.9928 - val_loss: 0.4536 - val_accuracy: 0.8681
# Epoch 37/50
# 118/118 [==============================] - 7s 60ms/step - loss: 0.0449 - accuracy: 0.9865 - val_loss: 0.4581 - val_accuracy: 0.8564
# Epoch 38/50
# 118/118 [==============================] - 8s 63ms/step - loss: 0.0437 - accuracy: 0.9875 - val_loss: 0.4419 - val_accuracy: 0.8745
# Epoch 39/50
# 118/118 [==============================] - 7s 60ms/step - loss: 0.0258 - accuracy: 0.9910 - val_loss: 0.3583 - val_accuracy: 0.8979
# Epoch 40/50
# 118/118 [==============================] - 8s 63ms/step - loss: 0.0065 - accuracy: 0.9992 - val_loss: 0.3718 - val_accuracy: 0.8936
# Epoch 41/50
# 118/118 [==============================] - 7s 61ms/step - loss: 0.0069 - accuracy: 0.9992 - val_loss: 0.3985 - val_accuracy: 0.8957
# Epoch 42/50
# 118/118 [==============================] - 7s 60ms/step - loss: 0.0116 - accuracy: 0.9976 - val_loss: 0.3864 - val_accuracy: 0.8809
# Epoch 43/50
# 118/118 [==============================] - 7s 61ms/step - loss: 0.0074 - accuracy: 0.9984 - val_loss: 0.4562 - val_accuracy: 0.8755
# Epoch 44/50
# 118/118 [==============================] - 7s 60ms/step - loss: 0.0094 - accuracy: 0.9971 - val_loss: 0.4033 - val_accuracy: 0.8830
# Epoch 45/50
# 118/118 [==============================] - 8s 63ms/step - loss: 0.0632 - accuracy: 0.9787 - val_loss: 0.3871 - val_accuracy: 0.9000
# Epoch 46/50
# 118/118 [==============================] - 8s 63ms/step - loss: 0.0133 - accuracy: 0.9960 - val_loss: 0.3667 - val_accuracy: 0.8979
# Epoch 47/50
# 118/118 [==============================] - 8s 64ms/step - loss: 0.0046 - accuracy: 0.9992 - val_loss: 0.3675 - val_accuracy: 0.8915
# Epoch 48/50
# 118/118 [==============================] - 8s 63ms/step - loss: 0.0073 - accuracy: 0.9981 - val_loss: 0.4118 - val_accuracy: 0.8691
# Epoch 49/50
# 118/118 [==============================] - 8s 63ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.3425 - val_accuracy: 0.9000
# Epoch 50/50
# 118/118 [==============================] - 7s 62ms/step - loss: 0.0053 - accuracy: 0.9992 - val_loss: 0.3575 - val_accuracy: 0.8989

# %%
# model.save("weight11.h5")

# %%
model.evaluate(val_data)
# Out:
# 30/30 [==============================] - 1s 35ms/step - loss: 0.3575 - accuracy: 0.8989
# [0.3575302064418793, 0.8989361524581909]

# %%
# from tensorflow import lite
# converter = lite.TFLiteConverter.from_keras_model(model)
# tfmodel = converter.convert()

# open('weight.tflite','wb').write(tfmodel)

# %%
plt.plot(history.history['accuracy'])
plt.title('Train model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.title('Train Model loss')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %%
plt.plot(history.history['val_accuracy'])
plt.title(' Val model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %%
plt.plot(history.history['val_loss'])
plt.title(' Val Model Loss')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %%
loss_train = history.history['loss']
loss_val = history.history['val_loss']
plt.plot(loss_train, 'g', label='Training loss')
plt.plot(loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
accuracy_train = history.history['accuracy']
accuracy_val = history.history['val_accuracy']
plt.plot(accuracy_train, 'g', label='Training accuracy')
plt.plot(accuracy_val, 'b', label='Validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
class_names={0:"Bacterialblight", 1:"Blast", 2:"Brownspot", 3:"Tungro"}

# %%
for images, labels in val_data.take(1):
    for i in range(6):
        print("True_class:",val_data.class_names[labels[i]])
        x = image.img_to_array(images[i])
        x = np.expand_dims(x, axis=0)
        p=np.argmax(model.predict(x))
        if p==0:
            print("Predicted Image: Bacterialblight")
        elif p==1:
            print("Predicted Image: Blast")
        elif p==2:
            print("Predicted Image: Brownspot")
        else:
            print("Predicted Image: Tungro")
        
        print("Predicted class:",p)
# Out:
# True_class: Blast
# Predicted Image: Blast
# Predicted class: 1
# True_class: Tungro
# Predicted Image: Tungro
# Predicted class: 3
# True_class: Brownspot
# Predicted Image: Brownspot
# Predicted class: 2
# True_class: Blast
# Predicted Image: Blast
# Predicted class: 1
# True_class: Tungro
# Predicted Image: Tungro
# Predicted class: 3
# True_class: Brownspot
# Predicted Image: Brownspot
# Predicted class: 2
