# %%
import tensorflow as tf
from tensorflow import keras 
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as img
# %matplotlib inline
import tensorflow.keras.backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from pylab import imread,subplot,imshow,show
import cv2
import os

# %%
train = ImageDataGenerator(rescale=1./255)
test =  ImageDataGenerator(rescale=1./255)
val =  ImageDataGenerator(rescale=1./255)

# %%
train='dataset/train/'

# %%
train_data = tf.keras.preprocessing.image_dataset_from_directory(
    train,
    validation_split=0.2,
    image_size=(224,224),
    batch_size=32,
    subset='training',
    seed=1000 )
# Out:
# Found 4704 files belonging to 4 classes.
# Using 3764 files for training.

# %%
val='dataset/train/'

# %%
val_data = tf.keras.preprocessing.image_dataset_from_directory(
    val,
    validation_split=0.2,
    image_size=(224,224),
    batch_size=32,
    subset='validation',
    seed=1000
    )
# Out:
# Found 4704 files belonging to 4 classes.
# Using 940 files for validation.

# %%
test='dataset/test/'

# %%
test_data=tf.keras.preprocessing.image_dataset_from_directory(
    test,
    image_size=(224,224),
    batch_size=32,
    seed=1000
    )
# Out:
# Found 1228 files belonging to 4 classes.

# %%
class_names = ['Bacterialblight', 'Blast', 'Brownspot', 'Tungro']

# %%
train_data.class_names = class_names
val_data.class_names = class_names

# %%
print(val_data)
# Out:
# <BatchDataset shapes: ((None, 224, 224, 3), (None,)), types: (tf.float32, tf.int32)>

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_data.take(1):
    for i in range(6):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(train_data.class_names[labels[i]])
        plt.axis("off")

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Input
from tensorflow.keras.layers import Dense

# %%
model=Sequential()

model.add(Conv2D(16,(3,3), activation='relu', input_shape=(224,224,3)))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32,(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32,(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32,(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(30,activation='relu'))
model.add(Dense(10,activation='relu'))
model.add(Dense(100,activation='relu'))
model.add(Dense(133,activation='relu'))
model.add(Dense(4,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 24, 32)        9248
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 30)                138270
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                310
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               1100
# _________________________________________________________________
# dense_3 (Dense)              (None, 133)               13433
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 536
# =================================================================
# Total params: 177,233
# Trainable params: 177,233
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(1e-4), loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
history = model.fit(train_data, validation_data=val_data, epochs=50)
# Out:
# Epoch 1/50
# 118/118 [==============================] - 18s 83ms/step - loss: 1.5163 - accuracy: 0.3804 - val_loss: 1.1079 - val_accuracy: 0.4745
# Epoch 2/50
# 118/118 [==============================] - 8s 70ms/step - loss: 0.9836 - accuracy: 0.6031 - val_loss: 0.8755 - val_accuracy: 0.6468
# Epoch 3/50
# 118/118 [==============================] - 9s 76ms/step - loss: 0.7844 - accuracy: 0.6974 - val_loss: 0.8346 - val_accuracy: 0.6734
# Epoch 4/50
# 118/118 [==============================] - 9s 73ms/step - loss: 0.6238 - accuracy: 0.7617 - val_loss: 0.5694 - val_accuracy: 0.7809
# Epoch 5/50
# 118/118 [==============================] - 8s 71ms/step - loss: 0.4955 - accuracy: 0.8108 - val_loss: 0.4990 - val_accuracy: 0.8000
# Epoch 6/50
# 118/118 [==============================] - 9s 71ms/step - loss: 0.4201 - accuracy: 0.8390 - val_loss: 0.4245 - val_accuracy: 0.8362
# Epoch 7/50
# 118/118 [==============================] - 8s 70ms/step - loss: 0.3345 - accuracy: 0.8746 - val_loss: 0.3461 - val_accuracy: 0.8745
# Epoch 8/50
# 118/118 [==============================] - 9s 71ms/step - loss: 0.2735 - accuracy: 0.9062 - val_loss: 0.2496 - val_accuracy: 0.9117
# Epoch 9/50
# 118/118 [==============================] - 9s 71ms/step - loss: 0.2174 - accuracy: 0.9222 - val_loss: 0.1916 - val_accuracy: 0.9277 - ac - ETA: 1s -
# Epoch 10/50
# 118/118 [==============================] - 9s 73ms/step - loss: 0.1556 - accuracy: 0.9503 - val_loss: 0.1689 - val_accuracy: 0.9404
# Epoch 11/50
# 118/118 [==============================] - 8s 71ms/step - loss: 0.1217 - accuracy: 0.9647 - val_loss: 0.2052 - val_accuracy: 0.9128
# Epoch 12/50
# 118/118 [==============================] - 8s 71ms/step - loss: 0.0957 - accuracy: 0.9700 - val_loss: 0.1188 - val_accuracy: 0.9521
# Epoch 13/50
# 118/118 [==============================] - 8s 70ms/step - loss: 0.1641 - accuracy: 0.9477 - val_loss: 0.1250 - val_accuracy: 0.9521
# Epoch 14/50
# 118/118 [==============================] - 8s 70ms/step - loss: 0.0655 - accuracy: 0.9865 - val_loss: 0.0806 - val_accuracy: 0.9734 0s - loss: 0
# Epoch 15/50
# 118/118 [==============================] - 8s 70ms/step - loss: 0.0532 - accuracy: 0.9878 - val_loss: 0.0887 - val_accuracy: 0.974535
# Epoch 16/50
# 118/118 [==============================] - 9s 71ms/step - loss: 0.0381 - accuracy: 0.9923 - val_loss: 0.0620 - val_accuracy: 0.9809
# Epoch 17/50
# 118/118 [==============================] - 8s 70ms/step - loss: 0.0341 - accuracy: 0.9936 - val_loss: 0.0749 - val_accuracy: 0.9787
# Epoch 18/50
# 118/118 [==============================] - 8s 70ms/step - loss: 0.0273 - accuracy: 0.9936 - val_loss: 0.0713 - val_accuracy: 0.9777
# Epoch 19/50
# 118/118 [==============================] - 8s 70ms/step - loss: 0.0241 - accuracy: 0.9939 - val_loss: 0.0493 - val_accuracy: 0.9894
# Epoch 20/50
# 118/118 [==============================] - 8s 71ms/step - loss: 0.0840 - accuracy: 0.9697 - val_loss: 0.0865 - val_accuracy: 0.9745
# Epoch 21/50
# 118/118 [==============================] - 8s 71ms/step - loss: 0.0217 - accuracy: 0.9963 - val_loss: 0.0425 - val_accuracy: 0.9862
# Epoch 22/50
# 118/118 [==============================] - 8s 71ms/step - loss: 0.0139 - accuracy: 0.9973 - val_loss: 0.0467 - val_accuracy: 0.9851
# Epoch 23/50
# 118/118 [==============================] - 8s 70ms/step - loss: 0.0162 - accuracy: 0.9955 - val_loss: 0.0493 - val_accuracy: 0.9862
# Epoch 24/50
# 118/118 [==============================] - 8s 71ms/step - loss: 0.0109 - accuracy: 0.9976 - val_loss: 0.0474 - val_accuracy: 0.9883
# Epoch 25/50
# 118/118 [==============================] - 8s 71ms/step - loss: 0.0094 - accuracy: 0.9979 - val_loss: 0.0473 - val_accuracy: 0.9872
# Epoch 26/50
# 118/118 [==============================] - 9s 72ms/step - loss: 0.0066 - accuracy: 0.9984 - val_loss: 0.0459 - val_accuracy: 0.9872
# Epoch 27/50
# 118/118 [==============================] - 8s 71ms/step - loss: 0.0075 - accuracy: 0.9984 - val_loss: 0.0534 - val_accuracy: 0.9883
# Epoch 28/50
# 118/118 [==============================] - 8s 71ms/step - loss: 0.2008 - accuracy: 0.9354 - val_loss: 0.0842 - val_accuracy: 0.9766
# Epoch 29/50
# 118/118 [==============================] - 8s 71ms/step - loss: 0.0183 - accuracy: 0.9965 - val_loss: 0.0642 - val_accuracy: 0.9840
# Epoch 30/50
# 118/118 [==============================] - 9s 73ms/step - loss: 0.0082 - accuracy: 0.9989 - val_loss: 0.0581 - val_accuracy: 0.9883
# Epoch 31/50
# 118/118 [==============================] - 9s 76ms/step - loss: 0.0056 - accuracy: 0.9992 - val_loss: 0.0540 - val_accuracy: 0.9872
# Epoch 32/50
# 118/118 [==============================] - 10s 82ms/step - loss: 0.0053 - accuracy: 0.9992 - val_loss: 0.0561 - val_accuracy: 0.9872
# Epoch 33/50
# 118/118 [==============================] - 10s 82ms/step - loss: 0.0039 - accuracy: 0.9995 - val_loss: 0.0607 - val_accuracy: 0.9862
# Epoch 34/50
# 118/118 [==============================] - 10s 82ms/step - loss: 0.0028 - accuracy: 0.9997 - val_loss: 0.0588 - val_accuracy: 0.9862
# Epoch 35/50
# 118/118 [==============================] - 10s 82ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0585 - val_accuracy: 0.9872
# Epoch 36/50
# 118/118 [==============================] - 10s 81ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0610 - val_accuracy: 0.9862
# Epoch 37/50
# 118/118 [==============================] - 9s 73ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0623 - val_accuracy: 0.9872
# Epoch 38/50
# 118/118 [==============================] - 8s 70ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0609 - val_accuracy: 0.9851
# Epoch 39/50
# 118/118 [==============================] - 8s 70ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0632 - val_accuracy: 0.9872
# Epoch 40/50
# 118/118 [==============================] - 8s 70ms/step - loss: 9.0937e-04 - accuracy: 1.0000 - val_loss: 0.0645 - val_accuracy: 0.9851
# Epoch 41/50
# 118/118 [==============================] - 9s 71ms/step - loss: 7.9723e-04 - accuracy: 1.0000 - val_loss: 0.0636 - val_accuracy: 0.9862
# Epoch 42/50
# 118/118 [==============================] - 8s 71ms/step - loss: 7.1255e-04 - accuracy: 1.0000 - val_loss: 0.0633 - val_accuracy: 0.9851
# Epoch 43/50
# 118/118 [==============================] - 8s 71ms/step - loss: 6.1892e-04 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 0.9851
# Epoch 44/50
# 118/118 [==============================] - 8s 71ms/step - loss: 5.5443e-04 - accuracy: 1.0000 - val_loss: 0.0651 - val_accuracy: 0.9851
# Epoch 45/50
# 118/118 [==============================] - 8s 71ms/step - loss: 5.0389e-04 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 0.9851
# Epoch 46/50
# 118/118 [==============================] - 8s 71ms/step - loss: 4.4569e-04 - accuracy: 1.0000 - val_loss: 0.0672 - val_accuracy: 0.9851
# Epoch 47/50
# 118/118 [==============================] - 8s 70ms/step - loss: 4.0845e-04 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9851
# Epoch 48/50
# 118/118 [==============================] - 8s 71ms/step - loss: 3.7512e-04 - accuracy: 1.0000 - val_loss: 0.0677 - val_accuracy: 0.9851
# Epoch 49/50
# 118/118 [==============================] - 8s 70ms/step - loss: 3.2597e-04 - accuracy: 1.0000 - val_loss: 0.0683 - val_accuracy: 0.9851
# Epoch 50/50
# 118/118 [==============================] - 9s 72ms/step - loss: 2.9464e-04 - accuracy: 1.0000 - val_loss: 0.0690 - val_accuracy: 0.9851

# %%
model.save("weight.h5")

# %%
model.evaluate(val_data)
# Out:
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0690 - accuracy: 0.9851
# [0.06897620856761932, 0.9851064085960388]

# %%
from tensorflow import lite
converter = lite.TFLiteConverter.from_keras_model(model)
tfmodel = converter.convert()

open('weight.tflite','wb').write(tfmodel)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Lenovo\AppData\Local\Temp\tmps9lx5422\assets
# 714592

# %%
plt.plot(history.history['accuracy'])
plt.title('Train model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.title('Train Model loss')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %%
plt.plot(history.history['val_accuracy'])
plt.title(' Val model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %%
plt.plot(history.history['val_loss'])
plt.title(' Val Model Loss')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %%
loss_train = history.history['loss']
loss_val = history.history['val_loss']
plt.plot(loss_train, 'g', label='Training loss')
plt.plot(loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
accuracy_train = history.history['accuracy']
accuracy_val = history.history['val_accuracy']
plt.plot(accuracy_train, 'g', label='Training accuracy')
plt.plot(accuracy_val, 'b', label='Validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
class_names={0:"Bacterialblight", 1:"Blast", 2:"Brownspot", 3:"Tungro"}

# %%
for images, labels in val_data.take(1):
    for i in range(6):
        print("True_class:",val_data.class_names[labels[i]])
        x = image.img_to_array(images[i])
        x = np.expand_dims(x, axis=0)
        p=np.argmax(model.predict(x))
        if p==0:
            print("Predicted Image: Bacterialblight")
        elif p==1:
            print("Predicted Image: Blast")
        elif p==2:
            print("Predicted Image: Brownspot")
        else:
            print("Predicted Image: Tungro")
        
        print("Predicted class:",p)
# Out:
# True_class: Blast
# Predicted Image: Blast
# Predicted class: 1
# True_class: Tungro
# Predicted Image: Tungro
# Predicted class: 3
# True_class: Brownspot
# Predicted Image: Brownspot
# Predicted class: 2
# True_class: Blast
# Predicted Image: Blast
# Predicted class: 1
# True_class: Tungro
# Predicted Image: Tungro
# Predicted class: 3
# True_class: Brownspot
# Predicted Image: Brownspot
# Predicted class: 2
